# %% [markdown]
# <a href="https://colab.research.google.com/github/Insanesami/insane-code/blob/main/samipandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets

# %%
import opendatasets as od

# %%
od.download("https://www.kaggle.com/datasets/thomasfranois/worlds-best-restaurants")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: samiakhtar47
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/thomasfranois/worlds-best-restaurants
# ...
# 100%|██████████| 10.2k/10.2k [00:00<00:00, 5.18MB/s]

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/worlds-best-restaurants/WorldsBestRestaurants.csv")

# %%
data.head()
# Out:
#    year  rank                restaurant     location         country  \
# 0  2002     1                  El Bulli        Roses           Spain
# 1  2002     2  Restaurant Gordon Ramsay       London  United Kingdom
# 2  2002     3        The French Laundry   Yountville   United States
# 3  2002     4                  Rockpool       Sydney       Australia
# 4  2002     5            Spoon des Iles  Ile Maurice       Mauritius
#
#          lat         lng
# 0  42.263949    3.179553
# 1  51.507218   -0.127586
# 2  38.401578 -122.360810
# 3 -33.868820  151.209295
# 4 -20.348404   57.552152

# %%
data.min()
# Out:
# year                2002
# rank                   1
# restaurant          1884
# location            Alba
# country        Argentina
# lat           -38.336369
# lng          -122.870051
# dtype: object

# %%
len(data)
# Out:
# 1050

# %%
data.shape
# Out:
# (1050, 7)

# %%
data.columns
# Out:
# Index(['year', 'rank', 'restaurant', 'location', 'country', 'lat', 'lng'], dtype='object')

# %%
len(data.columns)
# Out:
# 7

# %%
data.tail(10)
# Out:
#       year  rank             restaurant                     location  \
# 1040  2023    41            Le Calandre                       Rubano
# 1041  2023    42           Piazza Duomo                         Alba
# 1042  2023    43                    Leo                       Bogotá
# 1043  2023    44           Le Bernardin                     New York
# 1044  2023    45  Nobelhart & Schmutzig                       Berlin
# 1045  2023    46     Orfali Bros Bistro                        Dubai
# 1046  2023    47                  Mayta                         Lima
# 1047  2023    48        La Grenouillère  La Madelaine-sous-Montreuil
# 1048  2023    49                Rosetta                  Mexico City
# 1049  2023    50           The Chairman                    Hong Kong
#
#                    country        lat         lng
# 1040                 Italy  45.426238   11.793786
# 1041                 Italy  44.700953    8.035349
# 1042              Colombia   4.710989  -74.072092
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        1050 non-null   int64
#  1   rank        1050 non-null   int64
#  2   restaurant  1050 non-null   object
#  3   location    1050 non-null   object
#  4   country     1050 non-null   object
#  5   lat         1050 non-null   float64
#  6   lng         1050 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 57.5+ KB

# %%
data.describe()
# Out:
#               year         rank          lat          lng
# count  1050.000000  1050.000000  1050.000000  1050.000000
# mean   2012.142857    25.490476    35.231239     0.070343
# std       6.276788    14.432130    24.690886    61.607445
# min    2002.000000     1.000000   -38.336369  -122.870051
# 25%    2007.000000    13.000000    35.824923    -3.737738
# 50%    2012.000000    25.000000    43.318237     2.351377
# 75%    2017.000000    38.000000    48.857548    12.568337
# max    2023.000000    50.000000    63.843390   151.209295
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['year'].plot(kind='hist', bins=20, title='year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['rank'].plot(kind='hist', bins=20, title='rank')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
data.describe().transpose()
# Out:
#        count         mean        std          min          25%          50%  \
# year  1050.0  2012.142857   6.276788  2002.000000  2007.000000  2012.000000
# rank  1050.0    25.490476  14.432130     1.000000    13.000000    25.000000
# lat   1050.0    35.231239  24.690886   -38.336369    35.824923    43.318237
# lng   1050.0     0.070343  61.607445  -122.870051    -3.737738     2.351377
#
#               75%          max
# year  2017.000000  2023.000000
# rank    38.000000    50.000000
# lat     48.857548    63.843390
# lng     12.568337   151.209295

# %%
data.head(2)
# Out:
#    year  rank                restaurant location         country        lat  \
# 0  2002     1                  El Bulli    Roses           Spain  42.263949
# 1  2002     2  Restaurant Gordon Ramsay   London  United Kingdom  51.507218
#
#         lng
# 0  3.179553
# 1 -0.127586
